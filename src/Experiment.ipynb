# %%
import networkx as nx
from pyvis.network import Network
from dimcli.utils.networkviz import NetworkViz
import matplotlib.pyplot as plt
import pprint
from datetime import timedelta
import warnings

warnings.filterwarnings('ignore')

from queries import *
from eventgraphs import *


# Event graph configuration
# t_max = [<delta days>, <delta hours>] 
join_rule = {
                "t_max": timedelta(days=0, hours=3),
                "t_min": timedelta(days=0, hours=0.1),
                'event_diff_max':0.4,
                'join_by_subject': True
            }


def eventgraph_mimiciii(starttime, endtime):
    conn = get_db_connection()
    patients = get_patient_demography(conn, starttime, endtime)
    events_list = list()
    n = 0
    types = dict()
    for k, v in EVENTS.items():
        types[v[0]] = k
    for event_name in EVENTS:
        events = get_events(conn, event_name, starttime, endtime)
        for i, e in enumerate(events):
            e['i'] = i + n 
        n += len(events)
        print(event_name, len(events))
        events_list += events 
    #pprint.pprint(events_list)
    print("Total events: ", n)
    print("Total patients:", len(patients))
    A = build_eventgraph(patients, events_list, join_rule)
    print(A)
    G = nx.from_numpy_array(A)
    for e in events_list:
        e['t'] = str(e['t'])
    attrs = dict([(e['i'], e) for e in events_list])
    pprint.pprint(attrs)
    nx.set_node_attributes(G, attrs)

    g = NetworkViz(height=800, width=800, notebook=True, directed=True)
    g.barnes_hut()
    g.from_nx(G)
    g.show("mimic.html")
    #g.save_graph("mimic.html")

# %%
starttime = '2143-01-01'
endtime = '2143-01-02'
eventgraph_mimiciii(starttime, endtime)
# Out:
# admissions 3
# discharges 2
# icustays_in 3
# icustays_out 1
# callout 1
# transfer_in 8
# transfer_out 5
# cptevents 2
# diagnoses_icd 21
# drgcodes 5
# procedures_icd 8
# services 4
# Total events:  63
# Total patients: 13
#   (11, 12)	0.6864814814814815
#   (13, 15)	0.624074074074074
#   (16, 17)	0.4746296296296296
#   (19, 20)	0.5712037037037037
#   (19, 21)	1.1336111111111111
#   (21, 22)	0.4746296296296296
#   (5, 9)	1.3972222222222221
#   (5, 0)	1.7464814814814815
#   (5, 6)	1.7655555555555555
#   (5, 11)	1.7655555555555555
#   (5, 59)	1.7655555555555555
#   (10, 9)	1.3972222222222221
#   (10, 0)	1.7464814814814815
#   (10, 6)	1.7655555555555555
#   (10, 11)	1.5155555555555555
#   (10, 59)	1.7655555555555555
#   (18, 9)	1.3972222222222221
#   (18, 0)	1.7464814814814815
#   (18, 6)	1.7655555555555555
#   (18, 11)	1.7655555555555555
#   (18, 59)	1.7655555555555555
#   (9, 0)	1.3492592592592594
#   (9, 6)	1.3683333333333334
#   (9, 11)	1.3683333333333334
#   (9, 59)	1.3683333333333334
#   :	:
#   (55, 22)	1.7725925925925927
#   (56, 8)	1.547962962962963
#   (56, 16)	1.547962962962963
#   (56, 21)	1.547962962962963
#   (56, 62)	1.547962962962963
#   (56, 17)	1.7725925925925927
#   (56, 22)	1.7725925925925927
#   (57, 8)	1.547962962962963
#   (57, 16)	1.547962962962963
#   (57, 21)	1.547962962962963
#   (57, 62)	1.547962962962963
#   (57, 17)	1.7725925925925927
#   (57, 22)	1.7725925925925927
#   (58, 8)	1.547962962962963
#   (58, 16)	1.547962962962963
#   (58, 21)	1.547962962962963
#   (58, 62)	1.547962962962963
#   (58, 17)	1.7725925925925927
#   (58, 22)	1.7725925925925927
#   (8, 17)	1.2246296296296295
#   (8, 22)	1.2246296296296295
#   (16, 22)	1.2246296296296295
#   (21, 17)	1.2246296296296295
#   (62, 17)	1.2246296296296295
#   (62, 22)	1.2246296296296295
# {0: {'admission_location': 'TRANSFER FROM HOSP/EXTRAM',
#      'admission_type': 'EMERGENCY',
#      'diagnosis': 'MYOCARDIAL INFARCTION\\CATH',
#      'edouttime': None,
#      'edregtime': None,
#      'has_chartevents_data': 1,
#      'hospital_expire_flag': 0,
#      'i': 0,
#      'id': '6223-120691',
#      't': '2143-01-01 12:09:00',
#      'type': 1},
#  1: {'admission_location': 'PHYS REFERRAL/NORMAL DELI',
#      'admission_type': 'URGENT',
#      'diagnosis': 'CHEST PAIN;SOB',
#      'edouttime': None,
#      'edregtime': None,
#      'has_chartevents_data': 1,
#      'hospital_expire_flag': 0,
#      'i': 1,
#      'id': '11206-110388',
#      't': '2143-01-01 13:31:00',
#      'type': 1},
#  2: {'admission_location': 'PHYS REFERRAL/NORMAL DELI',
#      'admission_type': 'EMERGENCY',
#      'diagnosis': 'INFECTED WOUND,RIGHT THIGH',
#      'edouttime': None,
#      'edregtime': None,
#      'has_chartevents_data': 0,
#      'hospital_expire_flag': 0,
#      'i': 2,
#      'id': '8678-109128',
#      't': '2143-01-01 16:49:00',
#      'type': 1},
#  3: {'admission_type': 'ELECTIVE',
#      'deathtime': None,
#      'diagnosis': 'MITRAL REGURGITATION\\MITRAL VALVE REPLACEMENT,HEART PORT '
#                   'MINIMALLY INVASIVE /SDA',
#      'discharge_location': 'HOME HEALTH CARE',
#      'has_chartevents_data': 1,
#      'hospital_expire_flag': 0,
#      'i': 3,
#      'id': '27286-115189',
#      't': '2143-01-01 15:00:00',
#      'type': 2},
#  4: {'admission_type': 'URGENT',
#      'deathtime': None,
#      'diagnosis': 'NECROTIZING PANCREATITIS',
#      'discharge_location': 'HOME',
#      'has_chartevents_data': 1,
#      'hospital_expire_flag': 0,
#      'i': 4,
#      'id': '15975-178167',
#      't': '2143-01-01 18:00:00',
#      'type': 2},
#  5: {'dbsource': 'metavision',
#      'first_careunit': 'MICU',
#      'first_wardid': 50,
#      'i': 5,
#      'icustay_id': 203254,
#      'id': '92525-144175',
#      't': '2143-01-01 09:54:38',
#      'type': 3},
#  6: {'dbsource': 'carevue',
#      'first_careunit': 'CCU',
#      'first_wardid': 57,
#      'i': 6,
#      'icustay_id': 224554,
#      'id': '6223-120691',
#      't': '2143-01-01 12:12:26',
#      'type': 3},
#  7: {'dbsource': 'carevue',
#      'first_careunit': 'MICU',
#      'first_wardid': 52,
#      'i': 7,
#      'icustay_id': 287935,
#      'id': '30053-182184',
#      't': '2143-01-01 16:59:35',
#      'type': 3},
#  8: {'dbsource': 'carevue',
#      'i': 8,
#      'icustay_id': 260873,
#      'id': '23770-138681',
#      'last_careunit': 'MICU',
#      'last_wardid': 23,
#      'los': 1.3649,
#      't': '2143-01-01 19:38:38',
#      'type': 4},
#  9: {'acknowledge_status': 'Acknowledged',
#      'callout_outcome': 'Cancelled',
#      'callout_service': 'TRAUM',
#      'callout_status': 'Inactive',
#      'callout_wardid': 40,
#      'curr_careunit': 'TSICU',
#      'curr_wardid': 14,
#      'discharge_wardid': None,
#      'i': 9,
#      'id': '49984-151108',
#      'request_cdiff': 0,
#      'request_mrsa': 0,
#      'request_resp': 0,
#      'request_tele': 0,
#      'request_vre': 0,
#      'submit_careunit': 'TSICU',
#      'submit_wardid': 14,
#      't': '2143-01-01 11:06:08',
#      'type': 5},
#  10: {'curr_careunit': 'MICU',
#       'curr_wardid': 50.0,
#       'dbsource': 'metavision',
#       'eventtype': 'transfer',
#       'i': 10,
#       'icustay_id': 203254.0,
#       'id': '92525-144175',
#       'prev_careunit': None,
#       'prev_wardid': 45.0,
#       't': '2143-01-01 09:54:38',
#       'type': 6},
#  11: {'curr_careunit': 'CCU',
#       'curr_wardid': 57.0,
#       'dbsource': 'carevue',
#       'eventtype': 'admit',
#       'i': 11,
#       'icustay_id': 224554.0,
#       'id': '6223-120691',
#       'prev_careunit': None,
#       'prev_wardid': nan,
#       't': '2143-01-01 12:12:26',
#       'type': 6},
#  12: {'curr_careunit': None,
#       'curr_wardid': 7.0,
#       'dbsource': 'carevue',
#       'eventtype': 'admit',
#       'i': 12,
#       'icustay_id': nan,
#       'id': '11206-110388',
#       'prev_careunit': None,
#       'prev_wardid': nan,
#       't': '2143-01-01 13:31:00',
#       'type': 6},
#  13: {'curr_careunit': None,
#       'curr_wardid': 31.0,
#       'dbsource': 'carevue',
#       'eventtype': 'admit',
#       'i': 13,
#       'icustay_id': nan,
#       'id': '8678-109128',
#       'prev_careunit': None,
#       'prev_wardid': nan,
#       't': '2143-01-01 16:50:04',
#       'type': 6},
#  14: {'curr_careunit': 'MICU',
#       'curr_wardid': 52.0,
#       'dbsource': 'carevue',
#       'eventtype': 'transfer',
#       'i': 14,
#       'icustay_id': 287935.0,
#       'id': '30053-182184',
#       'prev_careunit': None,
#       'prev_wardid': 18.0,
#       't': '2143-01-01 16:59:35',
#       'type': 6},
#  15: {'curr_careunit': None,
#       'curr_wardid': nan,
#       'dbsource': 'carevue',
#       'eventtype': 'discharge',
#       'i': 15,
#       'icustay_id': nan,
#       'id': '15975-178167',
#       'prev_careunit': None,
#       'prev_wardid': 40.0,
#       't': '2143-01-01 17:57:24',
#       'type': 6},
#  16: {'curr_careunit': None,
#       'curr_wardid': 48.0,
#       'dbsource': 'carevue',
#       'eventtype': 'transfer',
#       'i': 16,
#       'icustay_id': nan,
#       'id': '23770-138681',
#       'prev_careunit': 'MICU',
#       'prev_wardid': 23.0,
#       't': '2143-01-01 19:38:38',
#       'type': 6},
#  17: {'curr_careunit': 'MICU',
#       'curr_wardid': 52.0,
#       'dbsource': 'carevue',
#       'eventtype': 'transfer',
#       'i': 17,
#       'icustay_id': 202321.0,
#       'id': '8914-130250',
#       'prev_careunit': 'MICU',
#       'prev_wardid': 52.0,
#       't': '2143-01-01 20:19:04',
#       'type': 6},
#  18: {'curr_careunit': None,
#       'curr_wardid': 45,
#       'dbsource': 'metavision',
#       'eventtype': 'transfer',
#       'i': 18,
#       'icustay_id': nan,
#       'id': '92525-144175',
#       'los': 160.47,
#       'prev_careunit': 'MICU',
#       'prev_wardid': 50.0,
#       't': '2143-01-01 09:54:38',
#       'type': 7},
#  19: {'curr_careunit': None,
#       'curr_wardid': 18,
#       'dbsource': 'carevue',
#       'eventtype': 'transfer',
#       'i': 19,
#       'icustay_id': nan,
#       'id': '30053-182184',
#       'los': 92.52,
#       'prev_careunit': None,
#       'prev_wardid': 18.0,
#       't': '2143-01-01 16:59:35',
#       'type': 7},
#  20: {'curr_careunit': None,
#       'curr_wardid': 40,
#       'dbsource': 'carevue',
#       'eventtype': 'transfer',
#       'i': 20,
#       'icustay_id': nan,
#       'id': '15975-178167',
#       'los': 88.75,
#       'prev_careunit': 'MICU',
#       'prev_wardid': 23.0,
#       't': '2143-01-01 17:57:24',
#       'type': 7},
#  21: {'curr_careunit': 'MICU',
#       'curr_wardid': 23,
#       'dbsource': 'carevue',
#       'eventtype': 'transfer',
#       'i': 21,
#       'icustay_id': 260873.0,
#       'id': '23770-138681',
#       'los': 29.11,
#       'prev_careunit': None,
#       'prev_wardid': 32.0,
#       't': '2143-01-01 19:38:38',
#       'type': 7},
#  22: {'curr_careunit': 'MICU',
#       'curr_wardid': 52,
#       'dbsource': 'carevue',
#       'eventtype': 'admit',
#       'i': 22,
#       'icustay_id': 202321.0,
#       'id': '8914-130250',
#       'los': 39.59,
#       'prev_careunit': None,
#       'prev_wardid': nan,
#       't': '2143-01-01 20:19:04',
#       'type': 7},
#  23: {'costcenter': 'Resp',
#       'cpt_cd': '94003',
#       'cpt_number': 94003,
#       'cpt_suffix': None,
#       'i': 23,
#       'id': '8914-130250',
#       'sectionheader': 'Medicine',
#       'subsectionheader': 'Pulmonary',
#       't': '2143-01-01 00:00:00',
#       'type': 11},
#  24: {'costcenter': 'Resp',
#       'cpt_cd': '94003',
#       'cpt_number': 94003,
#       'cpt_suffix': None,
#       'i': 24,
#       'id': '7229-130512',
#       'sectionheader': 'Medicine',
#       'subsectionheader': 'Pulmonary',
#       't': '2143-01-01 00:00:00',
#       'type': 11},
#  25: {'i': 25,
#       'icd9_code': '4240',
#       'id': '27286-115189',
#       'seq_num': 1,
#       't': '2143-01-01 15:00:00',
#       'type': 12},
#  26: {'i': 26,
#       'icd9_code': '42731',
#       'id': '27286-115189',
#       'seq_num': 2,
#       't': '2143-01-01 15:00:00',
#       'type': 12},
#  27: {'i': 27,
#       'icd9_code': '4019',
#       'id': '27286-115189',
#       'seq_num': 3,
#       't': '2143-01-01 15:00:00',
#       'type': 12},
#  28: {'i': 28,
#       'icd9_code': '2724',
#       'id': '27286-115189',
#       'seq_num': 4,
#       't': '2143-01-01 15:00:00',
#       'type': 12},
#  29: {'i': 29,
#       'icd9_code': '34690',
#       'id': '27286-115189',
#       'seq_num': 5,
#       't': '2143-01-01 15:00:00',
#       'type': 12},
#  30: {'i': 30,
#       'icd9_code': '7200',
#       'id': '27286-115189',
#       'seq_num': 6,
#       't': '2143-01-01 15:00:00',
#       'type': 12},
#  31: {'i': 31,
#       'icd9_code': '51881',
#       'id': '15975-178167',
#       'seq_num': 7,
#       't': '2143-01-01 18:00:00',
#       'type': 12},
#  32: {'i': 32,
#       'icd9_code': '27651',
#       'id': '15975-178167',
#       'seq_num': 8,
#       't': '2143-01-01 18:00:00',
#       'type': 12},
#  33: {'i': 33,
#       'icd9_code': '25000',
#       'id': '15975-178167',
#       'seq_num': 9,
#       't': '2143-01-01 18:00:00',
#       'type': 12},
#  34: {'i': 34,
#       'icd9_code': 'V1301',
#       'id': '15975-178167',
#       'seq_num': 10,
#       't': '2143-01-01 18:00:00',
#       'type': 12},
#  35: {'i': 35,
#       'icd9_code': '5770',
#       'id': '15975-178167',
#       'seq_num': 1,
#       't': '2143-01-01 18:00:00',
#       'type': 12},
#  36: {'i': 36,
#       'icd9_code': '3051',
#       'id': '15975-178167',
#       'seq_num': 12,
#       't': '2143-01-01 18:00:00',
#       'type': 12},
#  37: {'i': 37,
#       'icd9_code': 'V5867',
#       'id': '15975-178167',
#       'seq_num': 13,
#       't': '2143-01-01 18:00:00',
#       'type': 12},
#  38: {'i': 38,
#       'icd9_code': '78791',
#       'id': '15975-178167',
#       'seq_num': 14,
#       't': '2143-01-01 18:00:00',
#       'type': 12},
#  39: {'i': 39,
#       'icd9_code': '7850',
#       'id': '15975-178167',
#       'seq_num': 15,
#       't': '2143-01-01 18:00:00',
#       'type': 12},
#  40: {'i': 40,
#       'icd9_code': '53081',
#       'id': '15975-178167',
#       'seq_num': 11,
#       't': '2143-01-01 18:00:00',
#       'type': 12},
#  41: {'i': 41,
#       'icd9_code': '30390',
#       'id': '15975-178167',
#       'seq_num': 2,
#       't': '2143-01-01 18:00:00',
#       'type': 12},
#  42: {'i': 42,
#       'icd9_code': '29181',
#       'id': '15975-178167',
#       'seq_num': 3,
#       't': '2143-01-01 18:00:00',
#       'type': 12},
#  43: {'i': 43,
#       'icd9_code': '5119',
#       'id': '15975-178167',
#       'seq_num': 4,
#       't': '2143-01-01 18:00:00',
#       'type': 12},
#  44: {'i': 44,
#       'icd9_code': '7895',
#       'id': '15975-178167',
#       'seq_num': 5,
#       't': '2143-01-01 18:00:00',
#       'type': 12},
#  45: {'i': 45,
#       'icd9_code': '4280',
#       'id': '15975-178167',
#       'seq_num': 6,
#       't': '2143-01-01 18:00:00',
#       'type': 12},
#  46: {'description': 'Cardiac Valve Procedures w/o Cardiac Catheterization',
#       'drg_code': '1632',
#       'drg_mortality': 2.0,
#       'drg_severity': 2.0,
#       'drg_type': 'APR ',
#       'i': 46,
#       'id': '27286-115189',
#       't': '2143-01-01 15:00:00',
#       'type': 13},
#  47: {'description': 'Cardiac Valve Procedures w/o Cardiac Catheterization',
#       'drg_code': '1632',
#       'drg_mortality': 2.0,
#       'drg_severity': 2.0,
#       'drg_type': 'APR ',
#       'i': 47,
#       'id': '27286-115189',
#       't': '2143-01-01 15:00:00',
#       'type': 13},
#  48: {'description': 'CARDIAC VALVE & OTH MAJ CARDIOTHORACIC PROC W/O CARD '
#                      'CATH W/O CC/MCC',
#       'drg_code': '221',
#       'drg_mortality': nan,
#       'drg_severity': nan,
#       'drg_type': 'MS',
#       'i': 48,
#       'id': '27286-115189',
#       't': '2143-01-01 15:00:00',
#       'type': 13},
#  49: {'description': 'Disorders of Pancreas Except Malignancy',
#       'drg_code': '2824',
#       'drg_mortality': 4.0,
#       'drg_severity': 4.0,
#       'drg_type': 'APR ',
#       'i': 49,
#       'id': '15975-178167',
#       't': '2143-01-01 18:00:00',
#       'type': 13},
#  50: {'description': 'DISORDERS OF PANCREAS EXCEPT MALIGNANCY',
#       'drg_code': '204',
#       'drg_mortality': nan,
#       'drg_severity': nan,
#       'drg_type': 'HCFA',
#       'i': 50,
#       'id': '15975-178167',
#       't': '2143-01-01 18:00:00',
#       'type': 13},
#  51: {'i': 51,
#       'icd9_code': '3524',
#       'id': '27286-115189',
#       'seq_num': 1,
#       't': '2143-01-01 15:00:00',
#       'type': 19},
#  52: {'i': 52,
#       'icd9_code': '3961',
#       'id': '27286-115189',
#       'seq_num': 2,
#       't': '2143-01-01 15:00:00',
#       'type': 19},
#  53: {'i': 53,
#       'icd9_code': '8872',
#       'id': '27286-115189',
#       'seq_num': 3,
#       't': '2143-01-01 15:00:00',
#       'type': 19},
#  54: {'i': 54,
#       'icd9_code': '9672',
#       'id': '15975-178167',
#       'seq_num': 4,
#       't': '2143-01-01 18:00:00',
#       'type': 19},
#  55: {'i': 55,
#       'icd9_code': '9915',
#       'id': '15975-178167',
#       'seq_num': 1,
#       't': '2143-01-01 18:00:00',
#       'type': 19},
#  56: {'i': 56,
#       'icd9_code': '3893',
#       'id': '15975-178167',
#       'seq_num': 5,
#       't': '2143-01-01 18:00:00',
#       'type': 19},
#  57: {'i': 57,
#       'icd9_code': '9604',
#       'id': '15975-178167',
#       'seq_num': 2,
#       't': '2143-01-01 18:00:00',
#       'type': 19},
#  58: {'i': 58,
#       'icd9_code': '966',
#       'id': '15975-178167',
#       'seq_num': 3,
#       't': '2143-01-01 18:00:00',
#       'type': 19},
#  59: {'curr_service': 'CMED',
#       'i': 59,
#       'id': '6223-120691',
#       'prev_service': None,
#       't': '2143-01-01 12:12:26',
#       'type': 20},
#  60: {'curr_service': 'CSURG',
#       'i': 60,
#       'id': '11206-110388',
#       'prev_service': None,
#       't': '2143-01-01 13:31:00',
#       'type': 20},
#  61: {'curr_service': 'VSURG',
#       'i': 61,
#       'id': '8678-109128',
#       'prev_service': None,
#       't': '2143-01-01 16:50:04',
#       'type': 20},
#  62: {'curr_service': 'OMED',
#       'i': 62,
#       'id': '23770-138681',
#       'prev_service': 'MED',
#       't': '2143-01-01 19:38:38',
#       'type': 20}}
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
